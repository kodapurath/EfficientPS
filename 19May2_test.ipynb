# %% [markdown]
# <a href="https://colab.research.google.com/github/kodapurath/EfficientPS/blob/master/19May2_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Switch on gpu and open terminal

# %%
#cd ~
#wget https://repo.anaconda.com/archive/Anaconda3-2021.05-Linux-x86_64.sh
# bash Anaconda3-2021.05-Linux-x86_64.sh

after pressing necessary keys

# exit
# cd ---> contents
# git clone "https://github.com/DeepSceneSeg/EfficientPS"
# cd EfficientPS
# conda env create -n efficientPS_env --file=environment.yml
# conda activate efficientPS_env
# pip install -r requirements.txt
# pip uninstall numpy
# pip install numpy
# cd efficientNet
# python setup.py develop
# cd ..
# python setup.py develop

extras
# export PATH=$PATH:/root/anaconda3/condabin
#conda create env -n efficientPS_env --file=environment.yml

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=abhay.k-oric@ottonomy.io&password=asjaanya&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
# !unzip gtFine_trainvaltest.zip -d data/dwn_cityscapes
# !unzip leftImg8bit_trainvaltest.zip -d data/dwn_cityscapes
#put gtfine and leftimg in EfficientPS>data>cityscapes then run the pycococretortool script

# %%
#SKIP////do only if you get an error
# !pip install git+git://github.com/waspinator/pycococreator.git@0.2.0

# %%
#SHIP////do only if you get an error
# !python -m pip install cityscapesscripts

# %% [markdown]
# ![Screenshot from 2021-05-19 20-56-08.png](data:image/png;base64,...)

# %%
#REFER EfficientPS Documentation
#This automatically takes gtFine and leftImage folder from the data/dwn_cityscapes to /data/cityscapes
# !python tools/convert_cityscapes.py ./data/dwn_cityscapes/ ./data/cityscapes/

# %%
# !git clone https://github.com/mcordts/cityscapesScripts.git

# %%
# !pwd
# Out:
# /content

# %%
# %cd cityscapesScripts/cityscapesscripts/preparation
#DO FROM TERMINAL
# !python createPanopticImgs.py --dataset-folder ../../../data/dwn_cityscapes/gtFine --output-folder ../../../data/cityscapes/panoptic --set-names val

# %% [markdown]
# # **Test**

# %%
# !ls
# %cd EfficientPS/
# wget http://panoptic.cs.uni-freiburg.de/static/models/efficientPS_cityscapes.zip
# unzip efficientPS_cityscapes.zip
# Out:
# EfficientPS  sample_data
# /content/EfficientPS

# %%
# %cd ../../../
python tools/test.py configs/efficientPS_singlegpu_sample.py efficientPS_cityscapes/model/model.pth --eval panoptic

# %% [markdown]
# Tryin to draw mask

# %%
python tools/cityscapes_save_predictions.py configs/efficientPS_singlegpu_sample.py efficientPS_cityscapes/model/model.pth data/dwn_cityscapes/leftImg8bit/test/ result/
